# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
df = pd.read_csv('shape/count/count.csv')
df.head()
# Out:
#         left        top      right     bottom  id  NUMPOINTS
# 0 -46.616668  -8.533223 -45.616668  -9.533223   1          5
# 1 -46.616668  -9.533223 -45.616668 -10.533223   2          1
# 2 -46.616668 -10.533223 -45.616668 -11.533223   3          0
# 3 -46.616668 -11.533223 -45.616668 -12.533223   4          2
# 4 -46.616668 -12.533223 -45.616668 -13.533223   5          0

# %%
files = [os.path.join('data', file) for file in os.listdir('data')]
df = pd.read_csv(files[0])
df.head()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/adriano/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-32-6369fdb6b0bf>", line 2, in <module>
#     df = pd.read_csv(files[0])
#   File "/home/adriano/.local/lib/python3.7/site-packages/pandas/io/parsers.py", line 702, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "/home/adriano/.local/lib/python3.7/site-packages/pandas/io/parsers.py", line 411, in _read
#     compression = _infer_compression(filepath_or_buffer, compression)
#   File "/home/adriano/.local/lib/python3.7/site-packages/pandas/io/common.py", line 293, in _infer_compression
#     filepath_or_buffer = _stringify_path(filepath_or_buffer)
# ...
